# %%
# !pip install keras-core --upgrade
# !pip install -q keras-nlp --upgrade

# This sample uses Keras Core, the multi-backend version of Keras.
# The selected backend is TensorFlow (other supported backends are 'jax' and 'torch')
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
# Out:
# Requirement already satisfied: keras-core in /opt/conda/lib/python3.10/site-packages (0.1.7)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras-core) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras-core) (1.23.5)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras-core) (13.4.2)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras-core) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-core) (3.9.0)
# Requirement already satisfied: dm-tree in /opt/conda/lib/python3.10/site-packages (from keras-core) (0.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras-core) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras-core) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras-core) (0.1.2)

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import keras_core as keras
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Brief description of the problem and data
#
# We wanto identify tweets by whether they accurately classify a disaster or not. The data are tweets that are either classified as accurately classifies a disaster, (1), or is just a random text (classified as a 0).

# %%
train = pd.read_csv("/kaggle/input/nlp-getting-started/train.csv")
test = pd.read_csv("/kaggle/input/nlp-getting-started/test.csv")

# %%
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %% [markdown]
# # Explore the dataset

# %%
train["length"] = train["text"].apply(lambda x : len(x))
test["length"] = test["text"].apply(lambda x : len(x))

print("Train Length Stat")
print(train["length"].describe())
print()

print("Test Length Stat")
print(test["length"].describe())
# Out:
# Train Length Stat
# count    7613.000000
# mean      101.037436
# std        33.781325
# min         7.000000
# 25%        78.000000
# 50%       107.000000
# 75%       133.000000
# max       157.000000
# Name: length, dtype: float64
#
# Test Length Stat
# count    3263.000000
# mean      102.108183
# std        33.972158
# min         5.000000
# 25%        78.000000
# 50%       109.000000
# 75%       134.000000
# max       151.000000
# Name: length, dtype: float64

# %% [markdown]
# # Preprocess the data

# %%
import nltk
from nltk.corpus import stopwords
import re

# Download necessary NLTK data
nltk.download('stopwords')

# Define a function to preprocess the text
def preprocess_text(text):
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])

    # Remove punctuation and special characters
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)

    return text

# Apply preprocessing to the text column
train['text'] = train['text'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn.model_selection import train_test_split
# Ensure labels are numeric
train['target'] = train['target'].astype(int)
print(f"Labels dtype: {train['target'].dtype}")

X = train['text']
y = train['target']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3)
# Out:
# Labels dtype: int64

# %%
X_train
# Out:
# 4665     Bilsko suddenly I m inundated research   humo...
# 1241    Such beautiful architecture  NYC I love fire e...
# 1190    Leicester Merc   ICYMI    Ashes 2015  Australi...
# 3028    1 43 earthquake occurred near Mount St  Helens...
# 3581        Fatal attraction common n common  pain
#                               ...
# 3150    Emergency root canal    tookitlikeaman  lovemy...
# 7305     Jennife29916207 I thinking today I reading wi...
# 6766                                       Ayshun Tornado
# 2104    http   t co lMA39ZRWoY There way seemeth right...
# 4676                  Beyond bounds  till inundation rise
# Name: text, Length: 5329, dtype: object

# %% [markdown]
# ## Word Embeddings

# %%
from gensim.models import Word2Vec
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Step 1: Ensure tokenization is done correctly
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train['text'])

# Convert the text to sequences of integers
sequences = tokenizer.texts_to_sequences(train['text'])

# Step 2: Pad sequences
max_sequence_length = max([len(seq) for seq in sequences])
data = pad_sequences(sequences, maxlen=max_sequence_length)


word_index = tokenizer.word_index

# Word2Vec model
w2v_model = Word2Vec(sentences=sequences, vector_size=100, window=5, min_count=1, workers=4)
w2v_model.train(sequences, total_examples=len(train['text']), epochs=10)

# Convert words to vectors
embedding_matrix = np.zeros((len(tokenizer.word_index) + 1, 100))
for word, i in tokenizer.word_index.items():
    if word in w2v_model.wv:
        embedding_matrix[i] = w2v_model.wv[word]

# %% [markdown]
# ## Model creation

# %% [markdown]
# A little bit about the strategy: We're using word2vec and then LSTM to be able to classify these tweets. The first step it to have an embedding layer, and then add an LSTM which is used for longer word sequences so that we still maintain context between the words. After that, we use a sigmooid activation function to classify as either 0 or 1 since its a binary task.
#
# From my research, I found that this model arch is the best because it captures the meaning of the individual words while also maintaining context throughout the training.

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense

max_sequence_length = max([len(seq) for seq in sequences])
data = pad_sequences(sequences, maxlen=max_sequence_length)

model = Sequential()
model.add(Embedding(input_dim=len(word_index) + 1,
                    output_dim=100,
                    weights=[embedding_matrix],
                    input_length=max_sequence_length,
                    trainable=False))
model.add(LSTM(128, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

def create_model(lstm_units=128, optimizer='adam'):
    model = Sequential()
    model.add(Embedding(input_dim=len(word_index) + 1,
                        output_dim=100,
                        weights=[embedding_matrix],
                        input_length=max_sequence_length,
                        trainable=False))
    model.add(LSTM(lstm_units, return_sequences=False))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

model = KerasClassifier(build_fn=create_model, epochs=5, batch_size=32, verbose=1)


param_grid = {
    'lstm_units': [64, 128, 256],
    'optimizer': ['adam', 'rmsprop'],
    'batch_size': [32, 64],
    'epochs': [5, 10]
}

grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)
grid_result = grid.fit(data, train['target'])

print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
# Out:
# /tmp/ipykernel_32/281194523.py:16: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, epochs=5, batch_size=32, verbose=1)
# Epoch 1/5
# 159/159 [==============================] - 6s 18ms/step - loss: 0.6896 - accuracy: 0.5494
# Epoch 2/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 3/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 4/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 5/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6886 - accuracy: 0.5494
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6738 - accuracy: 0.6123
# Epoch 1/5
# 159/159 [==============================] - 6s 19ms/step - loss: 0.6821 - accuracy: 0.5801
# Epoch 2/5
# 159/159 [==============================] - 3s 20ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 3/5
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 4/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 5/5
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6806 - accuracy: 0.5801
# 80/80 [==============================] - 1s 9ms/step - loss: 0.6899 - accuracy: 0.5508
# Epoch 1/5
# 159/159 [==============================] - 6s 19ms/step - loss: 0.6826 - accuracy: 0.5804
# Epoch 2/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 3/5
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 4/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 5/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6801 - accuracy: 0.5816
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6916 - accuracy: 0.5479
# Epoch 1/5
# 159/159 [==============================] - 5s 18ms/step - loss: 0.6891 - accuracy: 0.5494
# Epoch 2/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 3/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 4/5
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 5/5
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6888 - accuracy: 0.5494
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6738 - accuracy: 0.6123
# Epoch 1/5
# 159/159 [==============================] - 5s 19ms/step - loss: 0.6824 - accuracy: 0.5801
# Epoch 2/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 3/5
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 4/5
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6803 - accuracy: 0.5801
# Epoch 5/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6811 - accuracy: 0.5801
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6888 - accuracy: 0.5508
# Epoch 1/5
# 159/159 [==============================] - 5s 19ms/step - loss: 0.6817 - accuracy: 0.5816
# Epoch 2/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6808 - accuracy: 0.5816
# Epoch 3/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 4/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 5/5
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6800 - accuracy: 0.5816
# 80/80 [==============================] - 1s 9ms/step - loss: 0.6989 - accuracy: 0.5479
# Epoch 1/5
# 159/159 [==============================] - 8s 34ms/step - loss: 0.6894 - accuracy: 0.5466
# Epoch 2/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6892 - accuracy: 0.5494
# Epoch 3/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 4/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 5/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6887 - accuracy: 0.5494
# 80/80 [==============================] - 3s 18ms/step - loss: 0.6769 - accuracy: 0.6123
# Epoch 1/5
# 159/159 [==============================] - 8s 34ms/step - loss: 0.6826 - accuracy: 0.5801
# Epoch 2/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 3/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 4/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 5/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6808 - accuracy: 0.5801
# 80/80 [==============================] - 2s 15ms/step - loss: 0.6892 - accuracy: 0.5508
# Epoch 1/5
# 159/159 [==============================] - 8s 34ms/step - loss: 0.6820 - accuracy: 0.5816
# Epoch 2/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6809 - accuracy: 0.5816
# Epoch 3/5
# 159/159 [==============================] - 6s 36ms/step - loss: 0.6799 - accuracy: 0.5816
# Epoch 4/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 5/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6802 - accuracy: 0.5816
# 80/80 [==============================] - 2s 15ms/step - loss: 0.6917 - accuracy: 0.5479
# Epoch 1/5
# 159/159 [==============================] - 8s 36ms/step - loss: 0.6892 - accuracy: 0.5494
# Epoch 2/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 3/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 4/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 5/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6887 - accuracy: 0.5494
# 80/80 [==============================] - 2s 14ms/step - loss: 0.6767 - accuracy: 0.6123
# Epoch 1/5
# 159/159 [==============================] - 8s 35ms/step - loss: 0.6816 - accuracy: 0.5769
# Epoch 2/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 3/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 4/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 5/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6809 - accuracy: 0.5801
# 80/80 [==============================] - 2s 16ms/step - loss: 0.6901 - accuracy: 0.5508
# Epoch 1/5
# 159/159 [==============================] - 8s 36ms/step - loss: 0.6816 - accuracy: 0.5816
# Epoch 2/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 3/5
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6806 - accuracy: 0.5816
# Epoch 4/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 5/5
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6806 - accuracy: 0.5816
# 80/80 [==============================] - 2s 15ms/step - loss: 0.6904 - accuracy: 0.5479
# Epoch 1/5
# 159/159 [==============================] - 14s 66ms/step - loss: 0.6896 - accuracy: 0.5494
# Epoch 2/5
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 3/5
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 4/5
# 159/159 [==============================] - 11s 66ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 5/5
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6886 - accuracy: 0.5494
# 80/80 [==============================] - 3s 27ms/step - loss: 0.6758 - accuracy: 0.6123
# Epoch 1/5
# 159/159 [==============================] - 13s 67ms/step - loss: 0.6832 - accuracy: 0.5801
# Epoch 2/5
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 3/5
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 4/5
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 5/5
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6807 - accuracy: 0.5801
# 80/80 [==============================] - 3s 28ms/step - loss: 0.6926 - accuracy: 0.5508
# Epoch 1/5
# 159/159 [==============================] - 13s 68ms/step - loss: 0.6819 - accuracy: 0.5816
# Epoch 2/5
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6819 - accuracy: 0.5816
# Epoch 3/5
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 4/5
# 159/159 [==============================] - 11s 70ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 5/5
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6803 - accuracy: 0.5816
# 80/80 [==============================] - 3s 27ms/step - loss: 0.6910 - accuracy: 0.5479
# Epoch 1/5
# 159/159 [==============================] - 13s 68ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 2/5
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 3/5
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 4/5
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 5/5
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6887 - accuracy: 0.5494
# 80/80 [==============================] - 3s 26ms/step - loss: 0.6753 - accuracy: 0.6123
# Epoch 1/5
# 159/159 [==============================] - 13s 65ms/step - loss: 0.6821 - accuracy: 0.5801
# Epoch 2/5
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 3/5
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 4/5
# 159/159 [==============================] - 11s 66ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 5/5
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6809 - accuracy: 0.5801
# 80/80 [==============================] - 3s 29ms/step - loss: 0.6890 - accuracy: 0.5508
# Epoch 1/5
# 159/159 [==============================] - 13s 67ms/step - loss: 0.6818 - accuracy: 0.5780
# Epoch 2/5
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 3/5
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6808 - accuracy: 0.5816
# Epoch 4/5
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 5/5
# 159/159 [==============================] - 11s 66ms/step - loss: 0.6801 - accuracy: 0.5816
# 80/80 [==============================] - 3s 26ms/step - loss: 0.6908 - accuracy: 0.5479
# Epoch 1/10
# 159/159 [==============================] - 6s 18ms/step - loss: 0.6895 - accuracy: 0.5494
# Epoch 2/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 3/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 4/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 5/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 6/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 7/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 8/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 9/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 10/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6768 - accuracy: 0.6123
# Epoch 1/10
# 159/159 [==============================] - 6s 19ms/step - loss: 0.6820 - accuracy: 0.5801
# Epoch 2/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 3/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6813 - accuracy: 0.5801
# Epoch 4/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 5/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 6/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 7/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 8/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 9/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 10/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6805 - accuracy: 0.5801
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6883 - accuracy: 0.5508
# Epoch 1/10
# 159/159 [==============================] - 6s 19ms/step - loss: 0.6820 - accuracy: 0.5816
# Epoch 2/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6796 - accuracy: 0.5816
# Epoch 3/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 4/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 5/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 6/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6798 - accuracy: 0.5816
# Epoch 7/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 8/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 9/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 10/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6800 - accuracy: 0.5816
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6897 - accuracy: 0.5479
# Epoch 1/10
# 159/159 [==============================] - 5s 19ms/step - loss: 0.6892 - accuracy: 0.5466
# Epoch 2/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 3/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 4/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 5/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 6/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 7/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 8/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 9/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 10/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6886 - accuracy: 0.5494
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6739 - accuracy: 0.6123
# Epoch 1/10
# 159/159 [==============================] - 5s 18ms/step - loss: 0.6816 - accuracy: 0.5801
# Epoch 2/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6813 - accuracy: 0.5801
# Epoch 3/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 4/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 5/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 6/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 7/10
# 159/159 [==============================] - 3s 20ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 8/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 9/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 10/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6806 - accuracy: 0.5801
# 80/80 [==============================] - 1s 8ms/step - loss: 0.6883 - accuracy: 0.5508
# Epoch 1/10
# 159/159 [==============================] - 5s 18ms/step - loss: 0.6818 - accuracy: 0.5816
# Epoch 2/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 3/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 4/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 5/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 6/10
# 159/159 [==============================] - 3s 20ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 7/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 8/10
# 159/159 [==============================] - 3s 18ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 9/10
# 159/159 [==============================] - 3s 19ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 10/10
# 159/159 [==============================] - 3s 20ms/step - loss: 0.6802 - accuracy: 0.5816
# 80/80 [==============================] - 2s 8ms/step - loss: 0.6924 - accuracy: 0.5479
# Epoch 1/10
# 159/159 [==============================] - 8s 34ms/step - loss: 0.6891 - accuracy: 0.5454
# Epoch 2/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6881 - accuracy: 0.5494
# Epoch 3/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 4/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 5/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 6/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 7/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 8/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6884 - accuracy: 0.5494
# Epoch 9/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 10/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6886 - accuracy: 0.5494
# 80/80 [==============================] - 2s 15ms/step - loss: 0.6771 - accuracy: 0.6123
# Epoch 1/10
# 159/159 [==============================] - 8s 34ms/step - loss: 0.6828 - accuracy: 0.5801
# Epoch 2/10
# 159/159 [==============================] - 5s 35ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 3/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 4/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 5/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 6/10
# 159/159 [==============================] - 6s 37ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 7/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 8/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6804 - accuracy: 0.5801
# Epoch 9/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 10/10
# 159/159 [==============================] - 6s 37ms/step - loss: 0.6807 - accuracy: 0.5801
# 80/80 [==============================] - 2s 15ms/step - loss: 0.6892 - accuracy: 0.5508
# Epoch 1/10
# 159/159 [==============================] - 8s 35ms/step - loss: 0.6828 - accuracy: 0.5816
# Epoch 2/10
# 159/159 [==============================] - 6s 36ms/step - loss: 0.6809 - accuracy: 0.5816
# Epoch 3/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 4/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 5/10
# 159/159 [==============================] - 6s 36ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 6/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 7/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 8/10
# 159/159 [==============================] - 6s 36ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 9/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 10/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6800 - accuracy: 0.5816
# 80/80 [==============================] - 2s 15ms/step - loss: 0.6898 - accuracy: 0.5479
# Epoch 1/10
# 159/159 [==============================] - 8s 34ms/step - loss: 0.6893 - accuracy: 0.5494
# Epoch 2/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 3/10
# 159/159 [==============================] - 6s 36ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 4/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 5/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 6/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 7/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 8/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 9/10
# 159/159 [==============================] - 6s 37ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 10/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6886 - accuracy: 0.5494
# 80/80 [==============================] - 2s 14ms/step - loss: 0.6752 - accuracy: 0.6123
# Epoch 1/10
# 159/159 [==============================] - 7s 33ms/step - loss: 0.6826 - accuracy: 0.5801
# Epoch 2/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6814 - accuracy: 0.5801
# Epoch 3/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 4/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 5/10
# 159/159 [==============================] - 6s 36ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 6/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 7/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 8/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 9/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 10/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6805 - accuracy: 0.5801
# 80/80 [==============================] - 2s 17ms/step - loss: 0.6886 - accuracy: 0.5508
# Epoch 1/10
# 159/159 [==============================] - 9s 34ms/step - loss: 0.6817 - accuracy: 0.5784
# Epoch 2/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6808 - accuracy: 0.5816
# Epoch 3/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6808 - accuracy: 0.5816
# Epoch 4/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 5/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 6/10
# 159/159 [==============================] - 6s 35ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 7/10
# 159/159 [==============================] - 5s 34ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 8/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 9/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 10/10
# 159/159 [==============================] - 5s 33ms/step - loss: 0.6802 - accuracy: 0.5816
# 80/80 [==============================] - 2s 15ms/step - loss: 0.6902 - accuracy: 0.5479
# Epoch 1/10
# 159/159 [==============================] - 13s 67ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 2/10
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 3/10
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 4/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 5/10
# 159/159 [==============================] - 11s 66ms/step - loss: 0.6884 - accuracy: 0.5494
# Epoch 6/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 7/10
# 159/159 [==============================] - 11s 70ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 8/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 9/10
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 10/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6885 - accuracy: 0.5494
# 80/80 [==============================] - 3s 27ms/step - loss: 0.6769 - accuracy: 0.6123
# Epoch 1/10
# 159/159 [==============================] - 13s 68ms/step - loss: 0.6825 - accuracy: 0.5781
# Epoch 2/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 3/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 4/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 5/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 6/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 7/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 8/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 9/10
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 10/10
# 159/159 [==============================] - 10s 66ms/step - loss: 0.6808 - accuracy: 0.5801
# 80/80 [==============================] - 3s 26ms/step - loss: 0.6906 - accuracy: 0.5508
# Epoch 1/10
# 159/159 [==============================] - 13s 67ms/step - loss: 0.6829 - accuracy: 0.5764
# Epoch 2/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 3/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 4/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 5/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 6/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 7/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 8/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 9/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 10/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6801 - accuracy: 0.5816
# 80/80 [==============================] - 3s 26ms/step - loss: 0.6896 - accuracy: 0.5479
# Epoch 1/10
# 159/159 [==============================] - 13s 66ms/step - loss: 0.6894 - accuracy: 0.5466
# Epoch 2/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 3/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 4/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 5/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 6/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 7/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 8/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 9/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 10/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6885 - accuracy: 0.5494
# 80/80 [==============================] - 3s 26ms/step - loss: 0.6803 - accuracy: 0.6123
# Epoch 1/10
# 159/159 [==============================] - 13s 67ms/step - loss: 0.6823 - accuracy: 0.5801
# Epoch 2/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 3/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 4/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 5/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 6/10
# 159/159 [==============================] - 11s 68ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 7/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 8/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 9/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6804 - accuracy: 0.5801
# Epoch 10/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6804 - accuracy: 0.5801
# 80/80 [==============================] - 3s 28ms/step - loss: 0.6894 - accuracy: 0.5508
# Epoch 1/10
# 159/159 [==============================] - 14s 68ms/step - loss: 0.6810 - accuracy: 0.5816
# Epoch 2/10
# 159/159 [==============================] - 11s 70ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 3/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 4/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 5/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 6/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 7/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6797 - accuracy: 0.5816
# Epoch 8/10
# 159/159 [==============================] - 11s 69ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 9/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 10/10
# 159/159 [==============================] - 11s 67ms/step - loss: 0.6801 - accuracy: 0.5816
# 80/80 [==============================] - 3s 28ms/step - loss: 0.6917 - accuracy: 0.5479
# Epoch 1/5
# 80/80 [==============================] - 4s 25ms/step - loss: 0.6897 - accuracy: 0.5494
# Epoch 2/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6884 - accuracy: 0.5494
# Epoch 3/5
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 4/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6882 - accuracy: 0.5494
# Epoch 5/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6889 - accuracy: 0.5494
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6777 - accuracy: 0.6123
# Epoch 1/5
# 80/80 [==============================] - 4s 24ms/step - loss: 0.6828 - accuracy: 0.5801
# Epoch 2/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 3/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 4/5
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 5/5
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6806 - accuracy: 0.5801
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6892 - accuracy: 0.5508
# Epoch 1/5
# 80/80 [==============================] - 5s 27ms/step - loss: 0.6832 - accuracy: 0.5816
# Epoch 2/5
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 3/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 4/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6808 - accuracy: 0.5816
# Epoch 5/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6795 - accuracy: 0.5816
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6886 - accuracy: 0.5479
# Epoch 1/5
# 80/80 [==============================] - 4s 25ms/step - loss: 0.6894 - accuracy: 0.5494
# Epoch 2/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 3/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 4/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 5/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6886 - accuracy: 0.5494
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6760 - accuracy: 0.6123
# Epoch 1/5
# 80/80 [==============================] - 4s 24ms/step - loss: 0.6824 - accuracy: 0.5801
# Epoch 2/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6813 - accuracy: 0.5801
# Epoch 3/5
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 4/5
# 80/80 [==============================] - 2s 27ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 5/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6809 - accuracy: 0.5801
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6888 - accuracy: 0.5508
# Epoch 1/5
# 80/80 [==============================] - 5s 25ms/step - loss: 0.6819 - accuracy: 0.5784
# Epoch 2/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 3/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 4/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 5/5
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6803 - accuracy: 0.5816
# 40/40 [==============================] - 1s 11ms/step - loss: 0.6908 - accuracy: 0.5479
# Epoch 1/5
# 80/80 [==============================] - 6s 43ms/step - loss: 0.6903 - accuracy: 0.5411
# Epoch 2/5
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 3/5
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6891 - accuracy: 0.5494
# Epoch 4/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 5/5
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6886 - accuracy: 0.5494
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6771 - accuracy: 0.6123
# Epoch 1/5
# 80/80 [==============================] - 6s 44ms/step - loss: 0.6819 - accuracy: 0.5801
# Epoch 2/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6815 - accuracy: 0.5801
# Epoch 3/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6814 - accuracy: 0.5801
# Epoch 4/5
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 5/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6806 - accuracy: 0.5801
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6917 - accuracy: 0.5508
# Epoch 1/5
# 80/80 [==============================] - 6s 43ms/step - loss: 0.6813 - accuracy: 0.5816
# Epoch 2/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6808 - accuracy: 0.5816
# Epoch 3/5
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 4/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 5/5
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6807 - accuracy: 0.5816
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6944 - accuracy: 0.5479
# Epoch 1/5
# 80/80 [==============================] - 6s 43ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 2/5
# 80/80 [==============================] - 4s 47ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 3/5
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 4/5
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 5/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6886 - accuracy: 0.5494
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6746 - accuracy: 0.6123
# Epoch 1/5
# 80/80 [==============================] - 6s 44ms/step - loss: 0.6822 - accuracy: 0.5801
# Epoch 2/5
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 3/5
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6803 - accuracy: 0.5801
# Epoch 4/5
# 80/80 [==============================] - 4s 49ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 5/5
# 80/80 [==============================] - 4s 47ms/step - loss: 0.6809 - accuracy: 0.5801
# 40/40 [==============================] - 2s 20ms/step - loss: 0.6883 - accuracy: 0.5508
# Epoch 1/5
# 80/80 [==============================] - 6s 45ms/step - loss: 0.6821 - accuracy: 0.5816
# Epoch 2/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 3/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 4/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 5/5
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6803 - accuracy: 0.5816
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6900 - accuracy: 0.5479
# Epoch 1/5
# 80/80 [==============================] - 10s 94ms/step - loss: 0.6891 - accuracy: 0.5494
# Epoch 2/5
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6878 - accuracy: 0.5494
# Epoch 3/5
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6898 - accuracy: 0.5494
# Epoch 4/5
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 5/5
# 80/80 [==============================] - 8s 97ms/step - loss: 0.6883 - accuracy: 0.5494
# 40/40 [==============================] - 2s 36ms/step - loss: 0.6793 - accuracy: 0.6123
# Epoch 1/5
# 80/80 [==============================] - 10s 93ms/step - loss: 0.6820 - accuracy: 0.5801
# Epoch 2/5
# 80/80 [==============================] - 8s 96ms/step - loss: 0.6817 - accuracy: 0.5801
# Epoch 3/5
# 80/80 [==============================] - 8s 97ms/step - loss: 0.6814 - accuracy: 0.5801
# Epoch 4/5
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 5/5
# 80/80 [==============================] - 8s 96ms/step - loss: 0.6807 - accuracy: 0.5801
# 40/40 [==============================] - 2s 36ms/step - loss: 0.6903 - accuracy: 0.5508
# Epoch 1/5
# 80/80 [==============================] - 10s 98ms/step - loss: 0.6823 - accuracy: 0.5816
# Epoch 2/5
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6809 - accuracy: 0.5816
# Epoch 3/5
# 80/80 [==============================] - 8s 94ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 4/5
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 5/5
# 80/80 [==============================] - 7s 94ms/step - loss: 0.6804 - accuracy: 0.5816
# 40/40 [==============================] - 2s 37ms/step - loss: 0.6917 - accuracy: 0.5479
# Epoch 1/5
# 80/80 [==============================] - 10s 92ms/step - loss: 0.6896 - accuracy: 0.5454
# Epoch 2/5
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 3/5
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 4/5
# 80/80 [==============================] - 8s 97ms/step - loss: 0.6884 - accuracy: 0.5494
# Epoch 5/5
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6887 - accuracy: 0.5494
# 40/40 [==============================] - 2s 36ms/step - loss: 0.6784 - accuracy: 0.6123
# Epoch 1/5
# 80/80 [==============================] - 11s 94ms/step - loss: 0.6821 - accuracy: 0.5801
# Epoch 2/5
# 80/80 [==============================] - 8s 99ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 3/5
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 4/5
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 5/5
# 80/80 [==============================] - 8s 94ms/step - loss: 0.6809 - accuracy: 0.5801
# 40/40 [==============================] - 2s 37ms/step - loss: 0.6882 - accuracy: 0.5508
# Epoch 1/5
# 80/80 [==============================] - 10s 93ms/step - loss: 0.6815 - accuracy: 0.5816
# Epoch 2/5
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 3/5
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 4/5
# 80/80 [==============================] - 8s 94ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 5/5
# 80/80 [==============================] - 8s 98ms/step - loss: 0.6800 - accuracy: 0.5816
# 40/40 [==============================] - 2s 36ms/step - loss: 0.6904 - accuracy: 0.5479
# Epoch 1/10
# 80/80 [==============================] - 5s 25ms/step - loss: 0.6898 - accuracy: 0.5494
# Epoch 2/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 3/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6884 - accuracy: 0.5494
# Epoch 4/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 5/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 6/10
# 80/80 [==============================] - 2s 26ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 7/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 8/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 9/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 10/10
# 80/80 [==============================] - 2s 26ms/step - loss: 0.6884 - accuracy: 0.5494
# 40/40 [==============================] - 1s 14ms/step - loss: 0.6763 - accuracy: 0.6123
# Epoch 1/10
# 80/80 [==============================] - 5s 25ms/step - loss: 0.6814 - accuracy: 0.5801
# Epoch 2/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6814 - accuracy: 0.5801
# Epoch 3/10
# 80/80 [==============================] - 2s 26ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 4/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6804 - accuracy: 0.5801
# Epoch 5/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 6/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 7/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 8/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 9/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 10/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6805 - accuracy: 0.5801
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6892 - accuracy: 0.5508
# Epoch 1/10
# 80/80 [==============================] - 4s 25ms/step - loss: 0.6826 - accuracy: 0.5816
# Epoch 2/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 3/10
# 80/80 [==============================] - 2s 27ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 4/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 5/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 6/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 7/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 8/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6799 - accuracy: 0.5816
# Epoch 9/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 10/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6801 - accuracy: 0.5816
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6930 - accuracy: 0.5479
# Epoch 1/10
# 80/80 [==============================] - 4s 24ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 2/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 3/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 4/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 5/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 6/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 7/10
# 80/80 [==============================] - 2s 26ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 8/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 9/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6883 - accuracy: 0.5494
# Epoch 10/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6886 - accuracy: 0.5494
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6755 - accuracy: 0.6123
# Epoch 1/10
# 80/80 [==============================] - 5s 24ms/step - loss: 0.6813 - accuracy: 0.5758
# Epoch 2/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6815 - accuracy: 0.5801
# Epoch 3/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 4/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 5/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 6/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 7/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6810 - accuracy: 0.5801
# Epoch 8/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 9/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 10/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6807 - accuracy: 0.5801
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6887 - accuracy: 0.5508
# Epoch 1/10
# 80/80 [==============================] - 4s 25ms/step - loss: 0.6821 - accuracy: 0.5800
# Epoch 2/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 3/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6808 - accuracy: 0.5816
# Epoch 4/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 5/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 6/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 7/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 8/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 9/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 10/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.6802 - accuracy: 0.5816
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6910 - accuracy: 0.5479
# Epoch 1/10
# 80/80 [==============================] - 6s 44ms/step - loss: 0.6897 - accuracy: 0.5494
# Epoch 2/10
# 80/80 [==============================] - 4s 48ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 3/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6883 - accuracy: 0.5494
# Epoch 4/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 5/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6893 - accuracy: 0.5494
# Epoch 6/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 7/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 8/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6884 - accuracy: 0.5494
# Epoch 9/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 10/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6884 - accuracy: 0.5494
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6765 - accuracy: 0.6123
# Epoch 1/10
# 80/80 [==============================] - 6s 44ms/step - loss: 0.6836 - accuracy: 0.5801
# Epoch 2/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 3/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 4/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 5/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 6/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 7/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 8/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 9/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6804 - accuracy: 0.5801
# Epoch 10/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6804 - accuracy: 0.5801
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6890 - accuracy: 0.5508
# Epoch 1/10
# 80/80 [==============================] - 6s 44ms/step - loss: 0.6830 - accuracy: 0.5776
# Epoch 2/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 3/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 4/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 5/10
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 6/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 7/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6810 - accuracy: 0.5816
# Epoch 8/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 9/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 10/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6800 - accuracy: 0.5816
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6918 - accuracy: 0.5479
# Epoch 1/10
# 80/80 [==============================] - 6s 44ms/step - loss: 0.6894 - accuracy: 0.5494
# Epoch 2/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 3/10
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 4/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 5/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 6/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 7/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 8/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 9/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 10/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6885 - accuracy: 0.5494
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6787 - accuracy: 0.6123
# Epoch 1/10
# 80/80 [==============================] - 7s 43ms/step - loss: 0.6811 - accuracy: 0.5801
# Epoch 2/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 3/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 4/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 5/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 6/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6804 - accuracy: 0.5801
# Epoch 7/10
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6809 - accuracy: 0.5801
# Epoch 8/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 9/10
# 80/80 [==============================] - 4s 47ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 10/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6805 - accuracy: 0.5801
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6885 - accuracy: 0.5508
# Epoch 1/10
# 80/80 [==============================] - 6s 44ms/step - loss: 0.6820 - accuracy: 0.5816
# Epoch 2/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 3/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 4/10
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 5/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 6/10
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 7/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 8/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 9/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 10/10
# 80/80 [==============================] - 3s 44ms/step - loss: 0.6804 - accuracy: 0.5816
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6917 - accuracy: 0.5479
# Epoch 1/10
# 80/80 [==============================] - 10s 91ms/step - loss: 0.6896 - accuracy: 0.5494
# Epoch 2/10
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 3/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6888 - accuracy: 0.5494
# Epoch 4/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 5/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 6/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 7/10
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 8/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 9/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 10/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6884 - accuracy: 0.5494
# 40/40 [==============================] - 2s 35ms/step - loss: 0.6755 - accuracy: 0.6123
# Epoch 1/10
# 80/80 [==============================] - 10s 90ms/step - loss: 0.6826 - accuracy: 0.5801
# Epoch 2/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6815 - accuracy: 0.5801
# Epoch 3/10
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 4/10
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6814 - accuracy: 0.5801
# Epoch 5/10
# 80/80 [==============================] - 7s 90ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 6/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6805 - accuracy: 0.5801
# Epoch 7/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 8/10
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 9/10
# 80/80 [==============================] - 7s 94ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 10/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6806 - accuracy: 0.5801
# 40/40 [==============================] - 2s 34ms/step - loss: 0.6896 - accuracy: 0.5508
# Epoch 1/10
# 80/80 [==============================] - 10s 96ms/step - loss: 0.6832 - accuracy: 0.5816
# Epoch 2/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 3/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6806 - accuracy: 0.5816
# Epoch 4/10
# 80/80 [==============================] - 7s 94ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 5/10
# 80/80 [==============================] - 8s 99ms/step - loss: 0.6803 - accuracy: 0.5816
# Epoch 6/10
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 7/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 8/10
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 9/10
# 80/80 [==============================] - 8s 97ms/step - loss: 0.6800 - accuracy: 0.5816
# Epoch 10/10
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6800 - accuracy: 0.5816
# 40/40 [==============================] - 2s 35ms/step - loss: 0.6905 - accuracy: 0.5479
# Epoch 1/10
# 80/80 [==============================] - 9s 90ms/step - loss: 0.6891 - accuracy: 0.5427
# Epoch 2/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 3/10
# 80/80 [==============================] - 8s 95ms/step - loss: 0.6889 - accuracy: 0.5494
# Epoch 4/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6890 - accuracy: 0.5494
# Epoch 5/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6886 - accuracy: 0.5494
# Epoch 6/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 7/10
# 80/80 [==============================] - 8s 94ms/step - loss: 0.6887 - accuracy: 0.5494
# Epoch 8/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 9/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6885 - accuracy: 0.5494
# Epoch 10/10
# 80/80 [==============================] - 7s 90ms/step - loss: 0.6888 - accuracy: 0.5494
# 40/40 [==============================] - 2s 35ms/step - loss: 0.6777 - accuracy: 0.6123
# Epoch 1/10
# 80/80 [==============================] - 10s 95ms/step - loss: 0.6817 - accuracy: 0.5801
# Epoch 2/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6812 - accuracy: 0.5801
# Epoch 3/10
# 80/80 [==============================] - 7s 88ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 4/10
# 80/80 [==============================] - 7s 89ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 5/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6808 - accuracy: 0.5801
# Epoch 6/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 7/10
# 80/80 [==============================] - 7s 90ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 8/10
# 80/80 [==============================] - 7s 90ms/step - loss: 0.6807 - accuracy: 0.5801
# Epoch 9/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6806 - accuracy: 0.5801
# Epoch 10/10
# 80/80 [==============================] - 8s 94ms/step - loss: 0.6807 - accuracy: 0.5801
# 40/40 [==============================] - 2s 37ms/step - loss: 0.6886 - accuracy: 0.5508
# Epoch 1/10
# 80/80 [==============================] - 9s 90ms/step - loss: 0.6821 - accuracy: 0.5816
# Epoch 2/10
# 80/80 [==============================] - 7s 89ms/step - loss: 0.6807 - accuracy: 0.5816
# Epoch 3/10
# 80/80 [==============================] - 7s 90ms/step - loss: 0.6806 - accuracy: 0.5816
# Epoch 4/10
# 80/80 [==============================] - 8s 96ms/step - loss: 0.6798 - accuracy: 0.5816
# Epoch 5/10
# 80/80 [==============================] - 7s 92ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 6/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6805 - accuracy: 0.5816
# Epoch 7/10
# 80/80 [==============================] - 7s 94ms/step - loss: 0.6802 - accuracy: 0.5816
# Epoch 8/10
# 80/80 [==============================] - 8s 96ms/step - loss: 0.6801 - accuracy: 0.5816
# Epoch 9/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6804 - accuracy: 0.5816
# Epoch 10/10
# 80/80 [==============================] - 7s 93ms/step - loss: 0.6802 - accuracy: 0.5816
# 40/40 [==============================] - 2s 35ms/step - loss: 0.6903 - accuracy: 0.5479
# Epoch 1/5
# 238/238 [==============================] - 7s 19ms/step - loss: 0.6845 - accuracy: 0.5703
# Epoch 2/5
# 238/238 [==============================] - 4s 19ms/step - loss: 0.6837 - accuracy: 0.5703
# Epoch 3/5
# 238/238 [==============================] - 4s 19ms/step - loss: 0.6835 - accuracy: 0.5703
# Epoch 4/5
# 238/238 [==============================] - 5s 19ms/step - loss: 0.6836 - accuracy: 0.5703
# Epoch 5/5
# 238/238 [==============================] - 4s 19ms/step - loss: 0.6836 - accuracy: 0.5703
# Best: 0.5703372557957967 using {'batch_size': 32, 'epochs': 5, 'lstm_units': 64, 'optimizer': 'adam'}

# %%
test_sequences = tokenizer.texts_to_sequences(test['text']) 
test_data = pad_sequences(test_sequences, maxlen=max_sequence_length)
predictions = grid_result.best_estimator_.predict(test_data)
# Out:
# 102/102 [==============================] - 1s 9ms/step

# %% [markdown]
# # Generate the submission file
#
# For each tweets in the test set, we predict if the given tweet is about a real disaster or not. If so, predict a 1. If not, predict a 0.
#
# The `submission.csv` file uses the following format:
# `id,target`

# %%
sample_submission = pd.read_csv("/kaggle/input/nlp-getting-started/sample_submission.csv")

# %%
sample_submission["target"] = np.argmax(grid_result.best_estimator_.predict(test_data), axis=1)
# Out:
# 102/102 [==============================] - 1s 9ms/step

# %%
sample_submission.to_csv("submission.csv", index=False)

# %% [markdown]
# ## Conclusion
# In conclusion, I found that the higher epochs (as expected) resulted in higher accuracy. I feel like if I was not approaching the GPU quota for the week, i would have been able to experiment with more hyperparameter tuning and run for way more epochs.
#
# In the future, I also feel like I'd explore using upsampling to generate more data, because these sort of models always work better with more data. I would also like to have better GPUs for running more data.
